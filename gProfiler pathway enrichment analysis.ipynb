# %%
import pandas as pd
from gprofiler import GProfiler

# %%
df = pd.read_csv("Supplemental Table 1 Identified OCD Genes.csv")
df = df[['GENE']]
df = df.dropna()
df
# Out:
#              GENE
# 0            DRD3
# 1          SLC1A1
# 2          SLC6A3
# 3           NRXN1
# 4            WWP1
# ..            ...
# 450         CBLN1
# 452  LOC100287225
# 454      SIGLECL1
# 455       SYNDIG1
# 456     LOC284930
#
# [445 rows x 1 columns]

# %%
gene_list = list(pd.unique(df.GENE))
len(gene_list)
# Out:
# 444

# %%
gp = GProfiler(return_dataframe=True)

# %%
initial_pea = gp.profile(organism='hsapiens', query=gene_list, no_evidences=False, )

# %%
initial_pea.sort_values('p_value')
# Out:
#     source      native                                           name  \
# 0    GO:BP  GO:0099537                       trans-synaptic signaling
# 1    GO:BP  GO:0099536                             synaptic signaling
# 2    GO:BP  GO:0098916           anterograde trans-synaptic signaling
# 3    GO:BP  GO:0007268                 chemical synaptic transmission
# 4    GO:CC  GO:0045202                                        synapse
# ..     ...         ...                                            ...
# 700  GO:BP  GO:0050709       negative regulation of protein secretion
# 701  GO:BP  GO:0006468                        protein phosphorylation
# 702  GO:BP  GO:0016477                                 cell migration
# 703  GO:MF  GO:0042802                      identical protein binding
# 704     WP   WP:WP4760  PKC-gamma calcium signaling pathway in ataxia
#
#           p_value  significant  \
# 0    1.499553e-32         True
# 1    1.992455e-32         True
# 2    4.698666e-32         True
# 3    4.698666e-32         True
# 4    9.637777e-32         True
# ..            ...          ...
# 700  4.760075e-02         True
# 701  4.958524e-02         True
# 702  4.958524e-02         True
# 703  4.990093e-02         True
# 704  4.995511e-02         True
#
#                                            description  term_size  query_size  \
# 0    "Cell-cell signaling in either direction acros...        736         351
# 1    "Cell-cell signaling to, from or within a syna...        760         351
# 2    "Cell-cell signaling from pre to post-synapse,...        727         351
# 3    "The vesicular release of classical neurotrans...        727         351
# 4    "The junction between an axon of one neuron an...       1382         360
# ..                                                 ...        ...         ...
# 700  "Any process that stops, prevents, or reduces ...         79         351
# 701  "The process of introducing a phosphate group ...       1684         351
# 702  "The controlled self-propelled movement of a c...       1684         351
# 703  "Interacting selectively and non-covalently wi...       2080         360
# 704      PKC-gamma calcium signaling pathway in ataxia         22         212
#
#      intersection_size  effective_domain_size  precision    recall    query  \
# 0                   78                  18092   0.222222  0.105978  query_1
# 1                   79                  18092   0.225071  0.103947  query_1
# 2                   77                  18092   0.219373  0.105915  query_1
# 3                   77                  18092   0.219373  0.105915  query_1
# 4                  102                  18963   0.283333  0.073806  query_1
# ..                 ...                    ...        ...       ...      ...
# 700                  9                  18092   0.025641  0.113924  query_1
# 701                 57                  18092   0.162393  0.033848  query_1
# 702                 57                  18092   0.162393  0.033848  query_1
# 703                 64                  18694   0.177778  0.030769  query_1
# 704                  5                   7399   0.023585  0.227273  query_1
#
#                                                parents  \
# 0                                         [GO:0099536]
# 1                                         [GO:0007267]
# 2                                         [GO:0099537]
# 3                                         [GO:0098916]
# 4                                         [GO:0030054]
# ..                                                 ...
# 700  [GO:0002792, GO:0009306, GO:0050708, GO:005122...
# 701                           [GO:0006464, GO:0016310]
# 702                                       [GO:0048870]
# 703                                       [GO:0005515]
# 704                                        [WP:000000]
#
#                                          intersections  \
# 0    [DRD3, SLC1A1, SLC6A3, NRXN1, DRD4, GRIK1, GRI...
# 1    [DRD3, SLC1A1, SLC6A3, NRXN1, DRD4, GRIK1, GRI...
# 2    [DRD3, SLC1A1, SLC6A3, NRXN1, DRD4, GRIK1, GRI...
# 3    [DRD3, SLC1A1, SLC6A3, NRXN1, DRD4, GRIK1, GRI...
# 4    [DRD3, SLC1A1, SLC6A3, NRXN1, DRD4, GRIA3, GRI...
# ..                                                 ...
# 700  [DRD3, DRD4, DRD2, ADRA2A, APOE, MTNR1B, UCP2,...
# 701  [NRXN1, DRD4, SMAD4, ANKK1, DRD2, DRD1, ADRA2A...
# 702  [SOD2, DRD2, DRD1, ADRA2A, APOE, CDH2, GSTP1, ...
# 703  [SLC1A1, DRD4, SMAD4, GRIK2, GRIK5, SOD2, DRD2...
# 704               [GRIA3, GRIA4, CACNA1A, RYR3, GNA11]
#
#                                              evidences
# 0    [[IBA, IC, IEA], [TAS], [IBA], [ISS, IEA], [IS...
# 1    [[IBA, IC, IEA], [TAS], [IBA], [ISS, IEA], [IS...
# 2    [[IBA, IC, IEA], [TAS], [IBA], [ISS, IEA], [IS...
# 3    [[IBA, IC, IEA], [TAS], [IBA], [ISS, IEA], [IS...
# 4    [[IEA], [ISS, IEA], [IBA, IEA], [ISS, TAS, NAS...
# ..                                                 ...
# 700  [[IDA], [IDA], [IDA, IEA], [IMP], [IMP], [IEA]...
# 701  [[IDA], [IDA], [ISS, IEA], [IEA], [IEA], [IEA]...
# 702  [[IMP], [ISS, IEA], [ISS, IEA], [IMP], [IDA, I...
# 703  [[IEA], [IPI], [IPI], [IEA], [IEA], [IPI, IEA]...
# 704                     [[WP], [WP], [WP], [WP], [WP]]
#
# [705 rows x 16 columns]

# %%
initial_pea.to_csv('initial_PEA_v_1.csv')
