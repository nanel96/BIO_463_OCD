# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('')
df
# Out:
#     source                                          term_name  \
# 0    GO:BP  G protein-coupled receptor signaling pathway, ...
# 1    GO:BP  adenylate cyclase-modulating G protein-coupled...
# 2    GO:BP       modulation of chemical synaptic transmission
# 3    GO:BP             regulation of trans-synaptic signaling
# 4    GO:BP  adenylate cyclase-inhibiting G protein-coupled...
# ..     ...                                                ...
# 144   REAC                                      Adrenoceptors
# 145   REAC         Interleukin-4 and Interleukin-13 signaling
# 146   REAC                                 Signaling by NTRKs
# 147   REAC  Activation of kainate receptors upon glutamate...
# 148   REAC                               Leishmania infection
#
#                 term_id  adjusted_p_value  negative_log10_of_adjusted_p_value  \
# 0            GO:0007187      7.956472e-16                           15.099279
# ...

# %%
g = sns.catplot(data = df, x = 'source', y = 'adjusted_p_value')
plt.yscale('log')
plt.gca().invert_yaxis()
plt.ylabel('P-value')
plt.xlabel('Database')
plt.savefig('p-values.png')
plt.show()
